# %%
dbutils.widgets.dropdown(name = 'environment', choices= ['dev', 'uat', 'prod'], defaultValue = 'dev', label = 'select your environment')
environment = dbutils.widgets.get('environment')

# %%
# %run "./04_common"

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.{db_name}.raw_traffic").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.{db_name}.raw_roads").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.{db_name}.silver_traffic").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.{db_name}.silver_roads").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.{db_name}.gold_traffic").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.{db_name}.gold_roads").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM traffic_{environment}_catalog.gx.data_quality_quarantine").show()

# %%
dbutils.widgets.dropdown(name = 'environment', choices= ['dev', 'uat', 'prod'], defaultValue = 'dev', label = 'select your environment')
environment = dbutils.widgets.get('environment')

# %%
spark.sql(f"SELECT COUNT(*) FROM {environment}_catalog.bronze.raw_traffic").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM {environment}_catalog.bronze.raw_roads").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM {environment}_catalog.silver.silver_traffic").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM {environment}_catalog.silver.silver_roads").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM {environment}_catalog.gold.gold_traffic").show()

# %%
spark.sql(f"SELECT COUNT(*) FROM {environment}_catalog.gold.gold_roads").show()
